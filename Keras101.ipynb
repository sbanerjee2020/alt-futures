# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sbanerjee2020/alt-futures/blob/master/Keras101.ipynb)

# %% [markdown]
# # Introduction
# Machine learning has become increasingly synonymous with deep learning (DL), artificial intelligence (AI) and neural networks (NNs). Posts on the machine learning subreddit almost exclusively relate to neural network based approaches. Here we will construct a simple Keras model to do basic predictions and illustrate some good practices.

# %% [markdown]
# # Why
#
# Tensor Flow (TF), Theano, Torch are among the most common DL libraries. TF syntax can be initially a little strange. Keras is effectively a [simplified intuitive API](https://blog.keras.io/keras-as-a-simplified-interface-to-tensorflow-tutorial.html) built on top of Tensor Flow or Theano (you select the backend configuration). So, unless you require that customisation or sophistication that comes with a lower level interface, Keras should be sufficient for your purposes.
#
# A helpful blog post from the popular [machinelearningmastery](http://machinelearningmastery.com/tutorial-first-neural-network-python-keras/) website. This website is actually quite an extensive and powerful resource on machine learning - but needs fundamental steps in any deep learning model construction (specifically, normalising/scaling the data and splitting the data into separate training, validation and test sets).
#
# While trying to improve accuracy we need to avoid  overfitting. Here we instill best practices for DL Training

# %% [markdown]
# # Google Drive
# Mechanics of Google Drive

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
import os
os.chdir("drive/app/Keras101")

# %%
#!rm  models/*.hdf5
# !ls -al models
# Out:
# total 23008
# drwxr-xr-x 2 root root  4096 Apr 18 02:08 .
# drwxr-xr-x 2 root root  4096 Apr  6 15:26 ..
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-01.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-02.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-03.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-04.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-05.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-06.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-07.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-08.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-09.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-1000.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-100.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-101.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-102.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-103.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-104.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-105.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-106.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-107.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-108.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-109.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-10.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-110.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-111.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-112.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-113.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-114.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-115.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-116.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-117.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-118.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-119.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-11.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-120.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-121.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-122.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-123.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-124.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-125.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-126.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-127.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-128.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-129.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-12.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-130.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-131.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-132.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-133.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-134.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-135.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-136.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-137.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-138.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-139.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-13.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-140.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-141.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-142.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-143.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-144.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-145.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-146.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-147.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-148.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-149.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-14.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-150.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-151.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-152.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-153.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:32 nn_weights-154.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-155.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-156.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-157.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-158.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-159.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-15.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-160.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-161.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-162.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-163.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-164.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-165.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-166.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-167.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-168.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-169.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-16.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-170.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-171.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-172.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-173.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-174.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-175.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-176.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-177.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-178.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-179.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-17.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-180.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-181.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-182.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-183.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-184.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-185.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-186.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-187.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-188.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-189.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-18.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-190.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-191.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-192.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-193.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-194.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-195.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-196.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-197.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-198.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-199.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-19.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-200.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:33 nn_weights-201.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-202.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-203.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-204.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-205.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-206.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-207.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-208.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-209.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-20.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-210.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-211.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-212.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-213.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-214.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-215.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-216.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-217.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-218.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-219.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-21.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-220.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-221.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-222.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-223.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-224.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-225.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-226.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-227.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-228.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-229.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-22.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-230.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-231.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-232.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-233.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-234.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-235.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-236.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-237.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-238.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-239.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-23.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-240.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-241.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-242.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-243.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:34 nn_weights-244.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-245.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-246.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-247.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-248.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-249.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-24.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-250.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-251.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-252.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-253.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-254.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-255.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-256.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-257.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-258.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-259.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-25.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-260.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-261.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-262.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-263.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-264.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-265.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-266.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-267.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-268.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-269.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-26.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-270.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-271.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-272.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-273.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-274.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-275.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-276.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-277.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-278.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-279.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-27.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-280.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-281.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-282.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-283.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-284.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-285.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-286.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-287.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-288.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:35 nn_weights-289.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-28.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-290.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-291.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-292.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-293.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-294.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-295.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-296.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-297.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-298.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-299.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-29.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-300.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-301.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-302.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-303.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-304.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-305.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-306.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-307.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-308.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-309.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-30.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-310.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-311.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-312.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-313.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-314.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-315.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-316.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-317.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-318.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-319.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-31.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-320.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-321.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-322.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-323.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-324.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-325.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-326.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-327.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-328.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-329.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-32.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-330.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:36 nn_weights-331.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-332.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-333.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-334.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-335.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-336.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-337.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-338.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-339.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-33.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-340.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-341.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-342.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-343.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-344.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-345.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-346.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-347.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-348.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-349.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-34.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-350.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-351.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-352.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-353.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-354.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-355.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-356.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-357.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-358.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-359.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-35.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-360.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-361.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-362.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-363.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-364.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-365.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-366.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-367.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-368.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-369.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-36.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-370.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-371.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-372.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-373.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-374.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-375.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-376.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:37 nn_weights-377.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-378.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-379.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-37.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-380.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-381.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-382.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-383.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-384.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-385.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-386.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-387.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-388.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-389.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-38.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-390.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-391.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-392.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-393.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-394.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-395.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-396.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-397.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-398.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-399.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-39.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-400.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-401.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-402.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-403.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-404.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-405.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-406.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-407.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-408.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-409.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-40.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-410.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-411.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-412.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-413.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-414.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-415.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-416.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-417.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-418.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-419.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-41.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-420.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-421.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-422.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:38 nn_weights-423.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-424.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-425.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-426.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-427.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-428.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-429.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-42.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-430.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-431.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-432.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-433.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-434.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-435.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-436.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-437.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-438.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-439.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-43.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-440.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-441.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-442.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-443.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-444.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-445.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-446.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-447.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-448.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-449.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:29 nn_weights-44.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-450.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-451.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-452.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-453.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-454.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-455.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-456.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-457.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-458.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-459.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-45.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-460.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-461.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-462.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-463.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-464.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-465.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-466.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-467.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-468.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-469.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-46.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-470.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:39 nn_weights-471.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-472.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-473.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-474.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-475.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-476.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-477.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-478.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-479.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-47.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-480.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-481.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-482.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-483.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-484.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-485.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-486.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-487.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-488.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-489.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-48.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-490.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-491.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-492.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-493.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-494.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-495.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-496.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-497.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-498.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-499.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-49.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-500.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-501.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-502.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-503.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-504.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-505.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-506.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-507.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-508.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-509.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-50.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-510.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:40 nn_weights-511.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-512.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-513.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-514.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-515.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-516.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-517.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-518.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-519.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-51.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-520.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-521.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-522.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-523.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-524.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-525.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-526.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-527.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-528.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-529.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-52.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-530.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-531.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-532.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-533.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-534.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-535.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-536.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-537.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-538.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-539.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-53.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-540.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-541.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-542.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-543.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-544.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-545.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-546.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-547.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-548.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-549.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-54.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-550.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-551.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-552.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-553.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-554.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-555.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:41 nn_weights-556.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-557.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-558.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-559.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-55.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-560.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-561.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-562.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-563.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-564.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-565.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-566.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-567.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-568.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-569.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-56.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-570.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-571.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-572.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-573.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-574.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-575.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-576.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-577.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-578.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-579.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-57.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-580.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-581.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-582.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-583.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-584.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-585.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-586.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-587.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-588.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-589.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-58.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-590.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-591.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-592.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-593.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-594.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-595.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-596.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-597.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-598.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-599.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-59.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-600.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-601.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:42 nn_weights-602.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-603.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-604.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-605.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-606.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-607.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-608.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-609.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-60.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-610.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-611.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-612.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-613.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-614.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-615.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-616.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-617.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-618.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-619.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-61.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-620.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-621.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-622.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-623.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-624.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-625.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-626.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-627.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-628.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-629.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-62.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-630.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-631.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-632.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-633.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-634.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-635.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-636.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-637.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-638.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-639.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-63.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-640.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-641.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-642.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-643.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-644.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-645.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:43 nn_weights-646.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-647.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-648.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-649.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:30 nn_weights-64.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-650.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-651.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-652.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-653.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-654.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-655.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-656.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-657.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-658.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-659.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-65.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-660.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-661.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-662.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-663.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-664.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-665.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-666.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-667.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-668.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-669.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-66.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-670.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-671.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-672.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-673.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-674.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-675.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-676.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-677.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-678.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-679.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-67.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-680.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-681.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-682.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-683.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-684.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-685.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-686.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-687.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-688.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-689.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-68.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-690.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-691.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:44 nn_weights-692.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-693.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-694.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-695.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-696.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-697.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-698.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-699.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-69.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-700.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-701.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-702.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-703.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-704.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-705.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-706.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-707.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-708.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-709.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-70.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-710.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-711.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-712.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-713.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-714.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-715.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-716.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-717.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-718.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-719.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-71.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-720.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-721.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-722.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-723.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-724.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-725.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-726.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-727.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-728.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-729.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-72.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-730.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-731.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-732.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-733.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-734.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-735.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-736.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-737.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-738.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:45 nn_weights-739.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-73.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-740.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-741.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-742.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-743.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-744.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-745.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-746.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-747.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-748.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-749.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-74.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-750.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-751.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-752.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-753.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-754.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-755.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-756.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-757.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-758.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-759.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-75.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-760.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-761.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-762.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-763.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-764.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-765.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-766.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-767.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-768.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-769.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-76.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-770.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-771.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-772.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-773.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-774.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-775.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-776.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-777.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-778.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-779.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-77.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-780.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-781.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-782.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-783.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-784.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:46 nn_weights-785.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-786.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-787.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-788.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-789.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-78.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-790.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-791.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-792.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-793.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-794.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-795.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-796.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-797.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-798.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-799.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-79.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-800.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-801.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-802.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-803.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-804.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-805.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-806.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-807.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-808.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-809.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-80.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-810.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-811.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-812.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-813.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-814.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-815.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-816.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-817.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-818.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-819.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-81.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-820.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-821.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-822.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-823.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-824.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-825.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-826.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-827.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-828.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-829.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-82.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-830.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:47 nn_weights-831.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-832.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-833.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-834.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-835.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-836.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-837.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-838.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-839.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-83.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-840.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-841.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-842.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-843.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-844.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-845.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-846.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-847.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-848.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-849.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-84.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-850.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-851.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-852.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-853.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-854.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-855.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-856.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-857.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-858.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-859.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-85.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-860.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-861.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-862.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-863.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-864.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-865.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-866.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-867.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-868.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-869.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-86.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-870.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-871.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-872.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-873.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-874.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-875.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-876.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-877.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:48 nn_weights-878.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-879.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-87.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-880.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-881.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-882.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-883.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-884.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-885.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-886.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-887.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-888.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-889.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-88.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-890.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-891.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-892.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-893.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-894.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-895.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-896.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-897.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-898.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-899.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-89.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-900.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-901.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-902.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-903.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-904.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-905.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-906.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-907.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-908.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-909.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-90.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-910.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-911.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-912.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-913.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-914.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-915.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-916.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-917.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-918.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-919.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-91.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-920.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-921.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-922.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-923.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-924.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:49 nn_weights-925.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-926.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-927.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-928.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-929.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-92.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-930.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-931.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-932.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-933.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-934.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-935.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-936.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-937.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-938.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-939.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-93.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-940.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-941.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-942.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-943.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-944.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-945.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-946.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-947.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-948.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-949.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-94.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-950.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-951.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-952.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-953.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-954.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-955.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-956.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-957.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-958.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-959.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-95.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-960.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-961.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-962.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-963.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-964.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-965.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-966.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-967.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-968.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-969.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-96.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:50 nn_weights-970.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-971.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-972.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-973.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-974.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-975.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-976.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-977.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-978.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-979.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-97.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-980.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-981.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-982.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-983.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-984.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-985.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-986.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-987.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-988.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-989.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-98.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-990.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-991.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-992.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-993.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-994.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-995.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-996.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-997.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-998.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:51 nn_weights-999.hdf5
# -rw-r--r-- 1 root root 23488 Apr 22 21:31 nn_weights-99.hdf5

# %% [markdown]
# # Import Libraries

# %%
import keras
print(keras.__version__)

import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
import time
import pandas as pd
import requests

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2.1.5

# %% [markdown]
# # Dataset
# We are going to use the Pima Indians Diabetes dataset, a standard machine learning dataset with the objective to predict diabetes sufferers. It records various physiological measures of Pima Indians and whether subjects had developed diabetes. At just 768 rows, it’s a small dataset, especially in the context of deep learning. But its size will mean that we don’t need to worry about things like batch-size, CPUs vs GPUs and other computational concerns associated with complex NNs.
#
# We have downloaded the file and made it available on gdrive.

# %%
# fix random seed for reproducibility
seed = 155
np.random.seed(seed)



dataset = pd.read_csv("pima-indians-diabetes.csv", header=None).values
dataset
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
dataset
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %% [markdown]
# # Training vs. Test Data Set
#
# We have converted the dataset into a numpy array. The last column indicates whether that person had developed diabetes. We must separate the binary classifier and we also need to split the dataset into training and test sets. <br>
# The original model was trained on 576 rows (or 75 % of the dataset), so we'll retain that convention. <br>
# For now, we'll just randomly assign 576 rows to the training set, while the remaining rows will constitute the test set. <br>
# scikit's **train_test_split** function comes in handy here.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8], test_size=0.25, random_state=87)

# %% [markdown]
# # Model
# The starter model is a simple single layer fully connected neural network (this is generally not considered deep learning, where deepness is determined by the number of hidden layers). This is simple to build in Keras. We just initialise our model and then sequentially add layers (see GIF below). We also need to decide how to assess the **accuracy** of the model (called **loss**). As it’s a **classification** problem, **cross entropy** is the most appropriate measure of error (a **regression** task might use **mean squared error**).

# %%
np.random.seed(seed)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(5, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # CheckPoint
#
# We don’t explicitly create the input layer. Instead, we specify the number of neurons (or features) that feed into the first hidden layer. We also don’t need to worry about the input dimensions for subsequent layers, as the neurons in the previous layer form the input for the next layer. We’ve opted for 10 neurons in the hidden layer for now, but we’ll play around this value a little later. Our output has one neuron as it’s a binary classification problem (probability of belonging to positive group).
#
# The **activation** argument is the activation function for that layer. Activation functions combine the neuron inputs to produce an output. For example, a step function would mean a neuron fires (has a non-zero value) if the input values exceed a certain threshold. Various activation functions are described here. Finally, you’ll notice the optimizer argument is set to adam. **adam stands for Adaptive Moment Estimation**; it’s how the model tunes its parameters in order to minimise the training error (a good overview of deep learning optimization functions can be found [here](http://ruder.io/optimizing-gradient-descent/)).
#
# Keras allows you to observe the current state of your model at particular points in time, known as callbacks. One such callback is a **ModelCheckpoint**, which we will deploy to write the model parameters to a file. This will allow us to track the improvements in the predictive accuracy of the model on the test set over epochs. Note that this step is optional and can be safely ignored if you’re not interested in the performance of your model during intermediate steps. In fact, it’s quite a bad habit to compare model characteristics on the test set. Ideally, it should only be deployed at the very end.

# %%
# optional
from keras.callbacks import ModelCheckpoint
# specify filepath- this will write a new file for each epoch with the epoch number contained within the filename
filepath="models/nn_weights-{epoch:02d}.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=0, 
                                             save_weights_only=False, save_best_only=False, mode='max')

# %%
# !ls -al
# Out:
# total 1712
# drwxr-xr-x 2 root root   4096 Apr  6 15:26 .
# drwxr-xr-x 2 root root   4096 Mar 26 03:59 ..
# drwxr-xr-x 2 root root   4096 Apr 23 01:58 drive
# -rw-r--r-- 1 root root 614503 Apr 23 01:58 Keras101.ipynb
# -rw-r--r-- 1 root root  53304 Apr 20 06:02 keras_nns_0.png
# -rw-r--r-- 1 root root  55904 Apr 20 06:02 keras_nns_1.png
# -rw-r--r-- 1 root root  57460 Apr 20 06:02 keras_nns_2.png
# -rw-r--r-- 1 root root  58110 Apr 20 06:02 keras_nns_3.png
# -rw-r--r-- 1 root root  93442 Apr 20 06:02 keras_nns_4.png
# -rw-r--r-- 1 root root  94434 Apr 20 06:02 keras_nns_5.png
# -rw-r--r-- 1 root root  98867 Apr 20 06:02 keras_nns_6.png
# -rw-r--r-- 1 root root  99985 Apr 20 06:02 keras_nns_7.png
# -rw-r--r-- 1 root root 100287 Apr 20 06:02 keras_nns_8.png
# drwxr-xr-x 2 root root   4096 Apr 18 02:08 models
# -rw-r--r-- 1 root root  23775 Apr  6 07:07 pima-indians-diabetes.csv
# -rw-r--r-- 1 root root  21792 Apr 20 06:03 x-valid_1_.png
# -rw-r--r-- 1 root root  17932 Apr 20 06:03 x-valid_1.png
# -rw-r--r-- 1 root root  26897 Apr 20 06:03 x-valid_2_.png
# -rw-r--r-- 1 root root  21950 Apr 20 06:03 x-valid_2.png
# -rw-r--r-- 1 root root  32085 Apr 20 06:03 x-valid_3_.png
# -rw-r--r-- 1 root root  27122 Apr 20 06:03 x-valid_3.png
# -rw-r--r-- 1 root root  35645 Apr 20 06:03 x-valid_4_.png
# -rw-r--r-- 1 root root  32365 Apr 20 06:03 x-valid_4.png
# -rw-r--r-- 1 root root  39876 Apr 20 06:03 x-valid_5_.png
# -rw-r--r-- 1 root root  35856 Apr 20 06:03 x-valid_5.png
# -rw-r--r-- 1 root root  45440 Apr 20 06:03 x-valid_6__.png
# -rw-r--r-- 1 root root  42673 Apr 20 06:03 x-valid_6_.png

# %%
X_train.shape
# Out:
# (576, 8)

# %% [markdown]
# #  Fit
# We’re ready to fit our neural network to the training dataset. We pass the model the input and output as separate arguments. We may also specify the batch size (I’ve gone with a batch equal to the whole training set) and number of epochs (model iterations). More information on the fit method can be found here.

# %%
# verbose=0 suppresses the file writing message
# note that the fit method expects a list of callbacks
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=1000, verbose=0, batch_size=X_train.shape[0],
                                     callbacks=[checkpoint], initial_epoch=0)

# %% [markdown]
# #  Evaluate
# To assess the performance of your model on the test dataset, use the evaluate method.

# %%
# [loss, accuracy]
my_first_nn.evaluate(X_test, Y_test, verbose=0)
# Out:
# [0.5911805580059687, 0.6979166666666666]

# %% [markdown]
# # Next
#
# The values in the list are the model loss and accuracy, respectively. If you’re interested in how the training error changed over time, you can call my_first_nn_fitted.history.

# %%
# training loss and accuracy over the first five epochs
[my_first_nn_fitted.history['loss'][0:5], my_first_nn_fitted.history['acc'][0:5]]
# Out:
# [[4.176606178283691,
#   4.133935928344727,
#   4.081396102905273,
#   4.024094581604004,
#   3.9655141830444336],
#  [0.6128472089767456,
#   0.6059027910232544,
#   0.5954861044883728,
#   0.5902777910232544,
#   0.5833333134651184]]

# %% [markdown]
# # Visualize
#
# Visualise how the model performed on the test set over time. Remember that we saved the model weights to a file at each epoch. This means we can reproduce each intermediate model by loading the weights into an appropriately constructed (i.e. same number of layers/neurons) neural network.

# %%
temp_test_model = Sequential() # create model
temp_test_model.add(Dense(5, input_dim=8, activation='relu')) # hidden layer
temp_test_model.add(Dense(1, activation='sigmoid')) # output layer
temp_test_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
test_over_time = []
for i in range(len(my_first_nn_fitted.history['acc'])):
    k = i + 1
    temp_test_model.load_weights("models/nn_weights-%02d.hdf5" % k)
    scores = temp_test_model.evaluate(X_test, Y_test, verbose=0)
    # 0 is loss; 1 is accuracy
    test_over_time.append(scores)

# %%
# !ls -al models/nn_weights-00.hdf5
# Out:
# ls: cannot access 'models/nn_weights-00.hdf5': No such file or directory

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(range(len(my_first_nn_fitted.history['loss'])), my_first_nn_fitted.history['loss'],linestyle='-', color='blue',label='Training', lw=2)
ax1.plot(range(len(np.array(test_over_time)[:,0])), np.array(test_over_time)[:,0], linestyle='-', color='green',label='Test', lw=2)
ax2.plot(range(len(my_first_nn_fitted.history['acc'])), my_first_nn_fitted.history['acc'],linestyle='-', color='blue',label='Training', lw=2)
ax2.plot(range(len(np.array(test_over_time)[:,1])), np.array(test_over_time)[:,1], linestyle='-', color='green',label='Test', lw=2)
leg = ax1.legend(bbox_to_anchor=(0.7, 0.9), loc=2, borderaxespad=0.,fontsize=13)
ax1.set_xticklabels('')
#ax1.set_yscale('log')
ax2.set_xlabel('# Epochs',fontsize=14)
ax1.set_ylabel('Loss',fontsize=14)
ax2.set_ylabel('Accuracy',fontsize=14)
plt.show()

# %% [markdown]
# # Next
#
# Achieved about **75%** **accuracy** on the training set, which corresponds to **70 %** **accuracy** on the test set. As the performance on the two datasets is not hugely divergent, this suggests that our model does not suffer from significant overfitting. Recall that **95% accuracy** has been reported on this dataset, so we still have room for improvement. So how can we improve our basic model? Well, by stuffing more neurons in there, of course! We’ll opt for **1000** neurons in a single fully connected hidden layer.
#
# Let us wrap the model construction and performance evaluation in a function.

# %%
def runNN(X_train_set, Y_train_set, X_test_set, Y_test_set, n_neurons, n_epochs, seed=155,
          history=True, del_files=True, validation_split=0.0, early_stopping=None):
    np.random.seed(seed)
    nn_model = Sequential() # create model
    nn_model.add(Dense(n_neurons, input_dim=X_train_set.shape[1], activation='relu')) # hidden layer
    nn_model.add(Dense(1, activation='sigmoid')) # output layer
    nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model_callbacks = []
    if early_stopping is not None:
        model_callbacks = [early_stopping]
    if history:
        filepath="models/nn_weights_%dneurons-{epoch:02d}.hdf5" %n_neurons
        checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=0, save_weights_only=True,
                                     save_best_only=False, mode='max')
        model_callbacks.append(checkpoint)
        output = nn_model.fit(X_train_set, Y_train_set, epochs=n_epochs, verbose=0, 
                              batch_size=X_train_set.shape[0],callbacks=model_callbacks, 
                              initial_epoch=0, validation_split=validation_split).history
        time.sleep(0.1) # hack so that files can be opened in subsequent code
        temp_val_model = Sequential() # create model
        temp_val_model.add(Dense(n_neurons, input_dim=8, activation='relu')) # hidden layer
        temp_val_model.add(Dense(1, activation='sigmoid')) # output layer
        temp_val_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        test_over_time = []
        for i in range(len(output['loss'])):
            k = i + 1
            temp_val_model.load_weights("models/nn_weights_%dneurons-%02d.hdf5" % (n_neurons,k))
            scores = temp_val_model.evaluate(X_test_set, Y_test_set, verbose=0)
            test_over_time.append(scores)
            # delete files once we're done with them
            if del_files:
                os.remove("models/nn_weights_%dneurons-%02d.hdf5" % (n_neurons,k))
        test_over_time = np.array(test_over_time)
        output['test_loss'] = [row[0] for row in test_over_time]
        output['test_acc'] = [row[1] for row in test_over_time]
    else:
        model_output = nn_model.fit(X_train_set, Y_train_set, epochs=n_epochs, verbose=0,
                              batch_size=X_train_set.shape[0],initial_epoch=0,callbacks=model_callbacks,
                              validation_split=validation_split)
        validation_size = 0
        output = {}
        if validation_split>0:
            validation_scores = nn_model.evaluate(model_output.validation_data[0], 
                                             model_output.validation_data[1], verbose=0)
            validation_size = model_output.validation_data[0].shape[0]
            output['validation_loss'] = validation_scores[0]
            output['validation_acc'] = validation_scores[1]
        training_size = X_train.shape[0] - validation_size
        train_scores = nn_model.evaluate(X_train_set[0:training_size], 
                                         Y_train_set[0:training_size], verbose=0)
        test_scores = nn_model.evaluate(X_test_set, Y_test_set, verbose=0)
        output['train_loss'] = train_scores[0]
        output['train_acc'] = train_scores[1]
        output['test_loss'] = test_scores[0]
        output['test_acc'] = test_scores[1]
    return output

# %%
my_second_nn = runNN(X_train, Y_train, X_test, Y_test, 1000, 1000)
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(range(len(my_second_nn['loss'])),my_second_nn['loss'], color='blue',label='Training Set', lw=1.5)
ax1.plot(range(len(my_second_nn['test_loss'])),my_second_nn['test_loss'], color='green',label='Test Set', lw=1.5)
ax2.plot(range(len(my_second_nn['acc'])),my_second_nn['acc'], color='blue',label='Training Set', lw=1.5)
ax2.plot(range(len(my_second_nn['test_acc'])),my_second_nn['test_acc'], color='green',label='Test Set', lw=1.5)
leg = ax1.legend(bbox_to_anchor=(0.7, 0.9), loc=2, borderaxespad=0.,fontsize=13)
ax1.set_xticklabels('')
ax2.set_xlabel('# Epochs',fontsize=14)
ax1.set_ylabel('Loss',fontsize=14)
ax2.set_ylabel('Accuracy',fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Summary
#
# Notice a gradual reduction in the training error, without any corresponding improvement in the test prediction (it actually appears to get worse). This represents **textbook overfitting**. Our neural network model has fine-tuned its parameters to the training dataset, so that it performs poorly on any unseen data. In other words, the model is highly specialised to the training set and doesn't generalise well beyond the training data. It's analogous to including more complex interaction terms in a simple regression task (also known as the bias-variance tradeoff). A good analogy is a model that's trained to detect a specific species of bird. The more it trains, its ability to detect other bird species worsens.
#
# We didn't achieve our target of 95 % accuracy on the training set. It's possible that we would eventually hit this target if the model was allowed more time to improve itself. As the model has 9000 parameters (8x1000+ 1x1000), it can take many epochs to find every marginal gain. We could also decide to play around with the learning rate. But the model possesses an inherent flaw. **The data was not scaled and/or normalised**. Scaling/normalising the data traditionally involves linear transformation to **force all values within a specific interval** (e.g. between 0 and 1), while standardising typically transforms the inputs to have the **mean centred on zero with unit variance**. Either way, no input feature dominates the model and this forces consistent weights. For example, 5000 x 0.0002 = 2 x 0.5, so that weights differ by several orders of magnitude, **which could inhibit backpropagation**.
#
# Scaling/normalising is easy; we can just employ some tools from scikit-learn. Note that you should scale/normalise the training and test sets separately. Otherwise, you'd be using information from your test set to inform your model training (if in doubt, think what would Eminem do?). We'll opt for the unit variance with the mean centred on 0 approach.

# %%
scaler = StandardScaler()
nn_output_unscaled = runNN(X_train, Y_train, X_test, Y_test, 1000, 1000)
nn_output_scaled = runNN(scaler.fit_transform(X_train), Y_train, 
                         scaler.fit_transform(X_test), Y_test, 1000, 1000)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(range(len(nn_output_unscaled['loss'])), nn_output_unscaled['loss'], linestyle='-', color='blue',label='Training', lw=2)
ax1.plot(range(len(nn_output_unscaled['test_loss'])), nn_output_unscaled['test_loss'], linestyle='-', color='green',label='Test', lw=2)
ax1.plot(range(len(nn_output_scaled['loss'])), nn_output_scaled['loss'], linestyle='-', color='deepskyblue',label='Training (Standardised)', lw=2)
ax1.plot(range(len(nn_output_scaled['test_loss'])), nn_output_scaled['test_loss'], linestyle='-', color='lightgreen',label='Test (Standardised)', lw=2)
ax2.plot(range(len(nn_output_unscaled['acc'])), nn_output_unscaled['acc'], linestyle='-', color='blue',label='Training', lw=2)
ax2.plot(range(len(nn_output_unscaled['test_acc'])), nn_output_unscaled['test_acc'], linestyle='-', color='green',label='Test', lw=2)
ax2.plot(range(len(nn_output_scaled['acc'])), nn_output_scaled['acc'], linestyle='-', color='deepskyblue',label='Training (Standardised)', lw=2)
ax2.plot(range(len(nn_output_scaled['test_acc'])), nn_output_scaled['test_acc'], linestyle='-', color='lightgreen',label='Test (Standardised)', lw=2)
leg = ax1.legend(bbox_to_anchor=(0.6, 0.9), loc=2, borderaxespad=0.,fontsize=13)
ax1.set_xticklabels('')
ax2.set_xlabel('# Epochs',fontsize=14)
ax1.set_ylabel('Loss',fontsize=14)
ax2.set_ylabel('Accuracy',fontsize=14)
ax2.annotate('Overfitting starts', xy=(80, 0.8), xytext=(100, 0.5),fontsize=14,
            arrowprops=dict(facecolor='black', shrink=0.0,headwidth=10))
plt.tight_layout()
plt.show()

# %%
nn_output_scaled['acc'][-1]
# Out:
# 1.0

# %% [markdown]
# # Early Stopping
#
# We did it! By normalizing the input data, we surpassed that **95% accuracy benchmark** and even attained perfect accuracy on the training set. Maybe if we added more neurons, we could defy mathematical logic and beat perfection. More neurons, better accuracy! However, as the training error on the standardised inputs approached zero, the test error showed no improvement. In fact, it even appears to significantly worsen. In other words, we have another case of **overfitting**. On a positive note, this graph also demonstrates the benefits of standardising your input data (as long as you don't allow the model overfit).
#
# # Validation Set & Early Stopping
# Remember, a good model is one that generalises well to unseen data. As such, reductions in the training error are only beneficial if they coincide with improvements in the test accuracy. Ideally, we'd stop training the model when it's no longer improving the test accuracy (known as **early stopping**). This is the reasoning behind the validation set. During the training phase, the model parameters (node weights in the case of NNs) are tuned on the training data, while the accuracy of the model is regularly assessed on data that sits outside of the training data (i.e. the **validation set**). As long as the validation error is decreasing, the model can continue to fine tune its parameters. Though they may seem to conceptually fulfill the same role, just beware that the validation and test datasets should be strictly separated. As model training incorporated the validation set, predictive performance can only be determined on the test set (hence, the training/validation/test split convention).
#
# In Keras, we have two options to include a validation set. We can directly pass a validation set (inputs and labels separately). Alternatively, we can extract a subset of the training set (specified as a proportion of the training set- Keras will simply take the last n% of the training set). If you opt for the latter option, you may want to shuffle your training set, if you suspect row position is not purely random. For reasons of brevity, we'll assume that's not case here. To incorporate early stopping, we add an **EarlyStopping** callback to our model.
#
# As I cleverly anticipated that I would discuss early stopping, we can use the runNN function. We just need to specify the validation split (early stopping requires some type of validation set) and our early stopping criteria. I'm going to be patient and offer the model 20 epochs to demonstrate a reduction in the validation loss (you can define what qualifies as a reduction using the monitor and min_delta arguments). We'll define the validation set to be the last 20% of the training set, creating a **60/15/25 split**.

# %%
early_stop_crit = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, 
                                                patience=20, verbose=0, mode='auto')
nn_output_unscaled = runNN(X_train, Y_train, X_test, Y_test, 1000, 1000,
                                         validation_split=0.2, early_stopping=early_stop_crit)
nn_output_scaled = runNN(scaler.fit_transform(X_train), Y_train, scaler.fit_transform(X_test), 
                         Y_test, 1000, 1000,validation_split=0.2, early_stopping=early_stop_crit)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(range(len(nn_output_unscaled['loss'])), nn_output_unscaled['loss'], linestyle='-', color='blue',label='Training', lw=2)
ax1.plot(range(len(nn_output_unscaled['val_loss'])), nn_output_unscaled['val_loss'], linestyle='-', color='purple',label='Validation', lw=2)
ax1.plot(range(len(nn_output_unscaled['test_loss'])), nn_output_unscaled['test_loss'],linestyle='-', color='green',label='Test', lw=2)
ax1.plot(range(len(nn_output_scaled['loss'])), nn_output_scaled['loss'], linestyle='-', color='deepskyblue',label='Training (Standardised)', lw=2)
ax1.plot(range(len(nn_output_scaled['val_loss'])), nn_output_scaled['val_loss'], linestyle='-', color='mediumpurple',label='Validation (Standardised)', lw=2)
ax1.plot(range(len(nn_output_scaled['test_loss'])), nn_output_scaled['test_loss'], linestyle='-', color='lightgreen',label='Test (Standardised)', lw=2)
ax2.plot(range(len(nn_output_unscaled['acc'])), nn_output_unscaled['acc'], linestyle='-', color='blue',label='Training', lw=2)
ax2.plot(range(len(nn_output_unscaled['val_acc'])), nn_output_unscaled['val_acc'], linestyle='-', color='purple',label='Validation', lw=2)
ax2.plot(range(len(nn_output_unscaled['test_acc'])), nn_output_unscaled['test_acc'],linestyle='-', color='green',label='Test', lw=2)
ax2.plot(range(len(nn_output_scaled['acc'])), nn_output_scaled['acc'], linestyle='-', color='deepskyblue',label='Training (Standardised)', lw=2)
ax2.plot(range(len(nn_output_scaled['val_acc'])), nn_output_scaled['val_acc'], linestyle='-', color='mediumpurple',label='Validation (Standardised)', lw=2)
ax2.plot(range(len(nn_output_scaled['test_acc'])), nn_output_scaled['test_acc'], linestyle='-', color='lightgreen',label='Test (Standardised)', lw=2)
leg = ax1.legend(bbox_to_anchor=(0.5, 0.95), loc=2, borderaxespad=0.,fontsize=13)
ax1.set_xticklabels('')
ax2.set_xlabel('# Epochs',fontsize=14)
ax1.set_ylabel('Loss',fontsize=14)
ax2.set_ylabel('Accuracy',fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# #  HyperParameter Tuning
#
#
# As well as preventing overfitting, one obvious advantage of early stopping is that it allows the model to stop early. You won't find that kind of insight on machinelearningmastery!!! While it may not appear hugely beneficial for our small simplified model, in the world of deep learning and driverless cars, this could save you some time. Of course, early stopping raises the prospect of premature stopping (i.e. terminating the training phase at a sub-optimal configuration). This risk can be mitigated by increasing the patience argument or loosening your definition of an improvement. As an aside, note the erratic behaviour exhibited by the model trained on unscaled data, which can be attributed to the instability of gradients derived from highly unbalanced input values.
#
# # Hyperparameter Tuning (& Cross-Validation)
# Hopefully, you've realised that less is sometimes more. Iterating over fewer epochs can actually improve the **predictive power** of the model. How about the number of nodes in the single hidden layer? Surely, we should just cramming them in there. Right? Well, this is known as **hyperparamater tuning/optimisation**- as opposed to parameter tuning, which is changing the model weights during the training phase. We can run multiple models with varying number of nodes (which we specify) and accept the version that performs best on the validation set. This is known as grid search (we're searching over a grid of values... yet more insightful insights you won't find anywhere else). Note that the process is similar if you want to tune other model hyperparameters (e.g. learning rate, batch size, activation functions, etc.). I'm actually going to compare the models on loss rather than accuracy; though it's less intuitive, it is more informative (an improvement in model loss doesn't necessarily coincide with better accuracy).

# %%
my_grid=[2,3,5,10,20,50,100,200,500,1000,5000]
nn_outputs = []
nn_outputs_early = []
early_stop_crit = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, 
                                                patience=20, verbose=0, mode='auto')
for i in my_grid:
    print(i)
    nn_output_unscaled = runNN(X_train, Y_train, X_test, Y_test, i, 1000, history=False)
    nn_output_scaled = runNN(scaler.fit_transform(X_train), Y_train,
                              scaler.fit_transform(X_test), Y_test, i, 1000, history=False)
    nn_output_unscaled_early = runNN(X_train, Y_train, X_test, Y_test, i, 1000, history=False,
                                   validation_split=0.2, early_stopping=early_stop_crit)
    nn_output_scaled_early = runNN(scaler.fit_transform(X_train), Y_train,
                                   scaler.fit_transform(X_test), Y_test, i, 1000, history=False,
                                   validation_split=0.2, early_stopping=early_stop_crit)
    nn_outputs.append([i, nn_output_unscaled['train_loss'],nn_output_unscaled['test_loss'], 
                       nn_output_scaled['train_loss'], nn_output_scaled['test_loss']])
    nn_outputs_early.append([i, nn_output_unscaled_early['train_loss'],nn_output_unscaled_early['validation_loss'],
                             nn_output_unscaled_early['test_loss'], nn_output_scaled_early['train_loss'], 
                             nn_output_scaled_early['validation_loss'], nn_output_scaled_early['test_loss']])
nn_outputs = np.array(nn_outputs)   
nn_outputs_early = np.array(nn_outputs_early)
# Out:
# 2
# 3
# 5
# 10
# 20
# 50
# 100
# 200
# 500
# 1000
# 5000

# %%
import matplotlib.ticker
from matplotlib.ticker import NullFormatter

fig1, (ax1, ax2) = plt.subplots(1,2)
ax1.plot(nn_outputs[:,0], nn_outputs[:,1], '--bo',label='Training', ms=7)
ax1.plot(nn_outputs[:,0], nn_outputs[:,2],  '--rs',label='Test', ms=7)
ax1.plot(nn_outputs[:,0], nn_outputs[:,3], '-bo',label='Training (Standardised)', ms=7)
ax1.plot(nn_outputs[:,0], nn_outputs[:,4],  '-rs',label='Test (Standardised)', ms=7)
ax1.set_xscale('log')
ax1.set_xticks([2,3,5,10,20,50,100,200,500,1000,5000])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax1.set_ylim([0,1.6])
ax1.set_xlim([1.8,6500])
ax1.set_ylabel('Loss',size=14)
ax2.plot(nn_outputs_early[:,0], nn_outputs_early[:,1], '--bo',label='Training', ms=7)
ax2.plot(nn_outputs_early[:,0], nn_outputs_early[:,2],  '--g^',label='Validation', ms=7)
ax2.plot(nn_outputs_early[:,0], nn_outputs_early[:,3], '--rs',label='Test', ms=7)
ax2.plot(nn_outputs_early[:,0], nn_outputs_early[:,4],  '-bo',label='Training (Standardised)', ms=7)
ax2.plot(nn_outputs_early[:,0], nn_outputs_early[:,5], '-g^',label='Validation (Standardised)', ms=7)
ax2.plot(nn_outputs_early[:,0], nn_outputs_early[:,6],  '-rs',label='Test (Standardised)', ms=7)
ax2.set_xscale('log')
ax2.set_xticks([2,3,5,10,20,50,100,200,500,1000,5000])
ax2.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax2.set_ylim([0,1.6])
ax2.set_xlim([1.8,6500])
ax1.set_xlabel('# Neurons (Log Scale)',size=14)
ax2.set_xlabel('# Neurons (Log Scale)',size=14)
ax1.set_title('Without Early Stopping')
ax2.set_title('With Early Stopping')
ax2.yaxis.set_major_formatter(NullFormatter())
plt.tight_layout()
ax2.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# number of neurons with lowest validation loss on the standardised inputs
my_grid[np.argmin(nn_outputs_early[:,5])]
# Out:
# 200

# %% [markdown]
# # Next
#
# The graph on the left doesn't include a validation set or early stopping. We can clearly see that standardising the data improves the model performance (last time I mention this, I promise!) and that more neurons doesn't necessarily equate to improved accuracy. Similar to training over endless epochs, more neurons just offers more opportunities to overfit the training data. Astute readers may have noticed spikes at 50 and 5000 neurons for the unscaled dataset (which are literally off the charts!!!). Remember that NN weights are usually randomly initialised (typically uniformly distributed but there are various alternatives). It's possible that a model was handed a bad set of initial weights (think trying to reach the mountaintop if you start in a flat valley). What we could do is take the best score across a number of executions (by changing the seed), though it seems that standardising your inputs is a sufficient defence against an unlucky start.
#
# If we add a validation set and allow early stopping (the graph on the right), we notice that the gap between the training accuracy and test accuracy is much narrower (indicative of reduced overfitting). Remember, we're trying to find the optimal number of neurons to include in the hidden layer. Ignoring the unscaled data from now on (I think I've made my point), we should opt for the value that returns the highest validation score. Using the test data here would be a form of cheating- remember we don't want the test data to inform the model. In that case, we'd settle on 200 neurons. But this was just one model execution, with the validation set comprising the last 20% of the training set. What would happen if the validation set was formed by the first 20%? We might well get a completely different answer. This the reasoning behind k-fold cross-validation. We'll run the model five times (hence, 5-fold cross-validation), taking non-overlapping 20% chunks for the validation set each time. The hyperparameter with the lowest average loss (or highest average accuracy, if you prefer) across those folds is deemed the winner.
#
# Rather than manually constructing the cross-validation datasets, we can harness the power (and convenience) of scikit-learn. We'll employ stratified cross-validation, which aims to replicate the label balance across each fold. I should point out that keras and scikit provides an elegant interface to combine grid search and cross-validation for hyperparameter tuning; I've seperated the processes for illustrative purposes.

# %%
from sklearn.model_selection import StratifiedKFold
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
all_kfolds_results=[]
for grid_vals in my_grid:
    kfolds_results = []
    print(grid_vals)
    for train_set, validation_set in kfold.split(X_train, Y_train):
        kfolds_results.append(runNN(scaler.fit_transform(X_train[train_set]), Y_train[train_set],
                                    scaler.fit_transform(X_train[validation_set]), Y_train[validation_set],
                                    grid_vals, 1000, history=False, validation_split=0.2,
                                    early_stopping=early_stop_crit)['test_loss'])
    all_kfolds_results.append(kfolds_results)
# Out:
# 2
# 3
# 5
# 10
# 20
# 50
# 100
# 200
# 500
# 1000
# 5000

# %%
my_grid[np.argmin(np.mean(all_kfolds_results,axis=1))]
# Out:
# 200

# %% [markdown]
# Looking at the averages alone, we'd conclude that 200 neurons is optimal. Those error bars represent the standard deviation, which measures the statistical uncertainty around those means. I won't delve into hypothesis testing (the merits of which can be debated), but superficially we can see that most of those errors bars overlap, meaning there's very little significant difference between each case (don't put that sentence in your paper submission). The size of the bars is worth noting, as it measures model stability. Depending on your circumstances, rather than overall accuracy, you may prefer a model that performs well consistently (small bars), as that could indicate it's more likely to maintain its performance on unseen data.
#
# Before you seek out an online t-test calculator, it's worth noting that the training/validation split can be sliced and diced in a whole multitude of ways (${{576}\choose{115}}&gt; 4\times10^{123}$). So far, we've assessed the hyperparameters on a single 5-fold cross validation configuration. Obviously, I don't recommend exhausting the full array of potential cross-validations, but it's good practice to compare your models across a number of different splits (called repeated cross-validation). Simply call RepeatedStratifiedKfold and specify the number of repeats. To illustrate it in action, I'll opt for 4 repeats (in practice, you'd probably want to increase this number).

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
# repeated stratified cross-validation
# only available with scikit-learn v0.19.0
# check your version:
# print('The scikit-learn version is {}.'.format(sklearn.__version__))
rkf = RepeatedStratifiedKFold(n_splits=5, n_repeats=4, random_state=seed)
all_kfolds_results = []
for grid_vals in my_grid:
    kfolds_results = []
    print(grid_vals)
    for train_set, validation_set in rkf.split(X_train, Y_train):
        kfolds_results.append(runNN(scaler.fit_transform(X_train[train_set]), Y_train[train_set],
                                        scaler.fit_transform(X_train[validation_set]), Y_train[validation_set],
                                        grid_vals, 1000, history=False, validation_split=0.2,
                                        early_stopping=early_stop_crit)['test_loss'])
    all_kfolds_results.append(kfolds_results)
#all_kfolds_results = np.load('all_kfolds_results_repeat_xval.npy')
# Out:
# 2
# 3
# 5
# 10
# 20
# 50
# 100
# 200
# 500
# 1000
# 5000

# %%
import matplotlib.ticker
import matplotlib.pyplot as plt


fig1, ax1 = plt.subplots()
for i, my_col in zip(range(4),['#1E434C','#ce3618','#C99E10','#9B4F0F']):
    plt.plot(my_grid, np.mean(np.array(all_kfolds_results)[:,range(i*5,(i+1)*5)],axis=1), 
                 label='restart #%d'%i, ms=7, color=my_col)
plt.errorbar(my_grid, np.mean(np.array(all_kfolds_results),axis=1), 
                 yerr=np.std(np.array(all_kfolds_results),axis=1),label='Average', ms=20,lw=5,color='#91d0ff')
plt.xscale('log')
plt.xticks([2,3,5,10,20,50,100,200,500,1000,5000])
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax1.set_ylim([0.43,0.57])
ax1.set_xlim([1.8,6500])
ax1.set_xlabel('# Neurons (Log Scale)',size=14)
ax1.set_ylabel('Validation Loss',size=14)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
my_grid[np.argmin(np.mean(np.array(all_kfolds_results),axis=1))]
# Out:
# 200

# %% [markdown]
# #  Appendix
#
# It's a close contest but a hidden layer with 200 neurons is the winner. We could shorten those error bars (and potentially get a different winner) by performing more repeats, but that's sufficient for my purposes.
#
# Finally, we can answer the age old question of the optimal number of neurons to put into a single hidden layer feed forward neural network model to predict diabetes sufferers among Pima Indians. It's 200... Or maybe 100. But it's certainly within those two numbers. Ah actually, that's not necessarily true. I need to look at 250. And 201...
#
# Summary
# This post was much more detailed (and wordy) than I had initially planned. Who knew there were so many ways to mess up a neural net? If you intend to actually gain some meaningful insights from your model (could happen...), then here are my top tips:
#
# Construct sensible training/validation/test splits
# Scale/Normalise/Standardise your input data
# Include early stopping to prevent overfitting (dropout could also work here)
# If conducting hyperparameter optimisation, select model with best performance on the validation set from repeated cross-validation
# Evaluate model on test set
# Thanks for reading!!! I need to lie down.
#
# Source Code
# The original code is available as a Jupyter notebook here.
#
# Appendix
# The code to produce those gifs is included below. Give a man a gif and he'll read your blog once, teach a man to gif and you'll attract many new readers (assuming your original code is adaquately linked).

# %%
import matplotlib.patches as patches

num_plot = 0
input_n = 8
input_cens = [0.5*i for i in range(input_n)]
# hl refers to hidden layer
hl0_n = 10
hl0_cens = [0.5*i-0.5 for i in range(hl0_n)]
hl1_n = 6
hl1_cens = [0.5*i+0.5 for i in range(hl1_n)]
output_n = 1
out_cens = np.mean(input_cens)
fig1, ax1 = plt.subplots()
fig1.set_size_inches(6, 6)
ax1.set_ylim([-0.75,4.75])
ax1.set_xlim([-0.75,4.75])
ax1.axison=False
plt.tight_layout()
for input_num,input_cen in enumerate(input_cens):
    ax1.add_artist(plt.Circle((0.5, input_cen), 0.2,  color='w', ec='k',clip_on=True, zorder=1))
    for hl0_cen in hl0_cens:
        plt.plot([0.5,1.5],[input_cen, hl0_cen],linestyle='-', color='black',label='Training', lw=1, zorder=0)
for hl0_cen in hl0_cens:
    ax1.add_artist(plt.Circle((1.5, hl0_cen), 0.2,  color='w', ec='k',clip_on=True, zorder=1))
plt.savefig('keras_nns_%d.png'%num_plot)
num_plot = num_plot + 1
for input_num,input_cen in enumerate(input_cens):
    plt.plot([0,0.5], [input_cen,input_cen],linestyle='-', color='black',lw=1.5, zorder=0)
    ax1.text(-0.35, input_cen-0.05, 'X%d'%(input_n-input_num-1), fontsize=10, fontweight='bold')
plt.savefig('keras_nns_%d.png'%num_plot)
num_plot = num_plot + 1
ax1.add_artist(patches.Rectangle((0.15, -0.5), 0.7, 4.5,alpha=0.5,linewidth=0,color='#96C0CE'))
ax1.text(0.1, 4.25, 'Input Layer', fontsize=11)
plt.savefig('keras_nns_%d.png'%num_plot)
num_plot = num_plot + 1
ax1.add_artist(patches.Rectangle((1.15, -1), 0.7, 5.25,alpha=0.5,linewidth=0,color='#BEB9B5'))
ax1.text(1, 4.5, 'Hidden Layer 1', fontsize=11)
plt.savefig('keras_nns_%d.png'%num_plot)
num_plot = num_plot + 1
for hl0_cen in hl0_cens:
    for hl1_cen in hl1_cens:
        plt.plot([1.5,2.5],[hl0_cen, hl1_cen],linestyle='-', color='black',label='Training', lw=1, zorder=0)
for hl1_cen in hl1_cens:
    ax1.add_artist(plt.Circle((2.5, hl1_cen), 0.2,  color='w', ec='k',clip_on=True, zorder=1))

plt.savefig('keras_nns_%d.png'%num_plot)
num_plot = num_plot + 1
ax1.add_artist(patches.Rectangle((2.15, 0), 0.7, 3.5,alpha=0.5,linewidth=0,color='#BEB9B5'))
ax1.text(2, 3.8, 'Hidden Layer 2', fontsize=11)
plt.savefig('keras_nns_%d.png'%num_plot)
num_plot = num_plot + 1
for hl1_cen in hl1_cens:
    for out_cen in [out_cens]:
        plt.plot([2.5,3.5],[hl1_cen, out_cen],linestyle='-', color='black',label='Training', lw=1, zorder=0)
for out_cen in [out_cens]:
    ax1.add_artist(plt.Circle((3.5, out_cen), 0.2,  color='w', ec='k',clip_on=True, zorder=1))
plt.savefig('keras_nns_%d.png'%num_plot)
num_plot = num_plot + 1
ax1.add_artist(patches.Rectangle((3.15, 1), 0.7, 1.5,alpha=0.5,linewidth=0,color='#C25B56'))
ax1.text(3.05, 2.7, 'Output Layer', fontsize=11)
plt.savefig('keras_nns_%d.png'%num_plot)
num_plot = num_plot + 1
plt.plot([3.5,4], [out_cen,out_cen],linestyle='-', color='black',lw=1.5, zorder=0)
ax1.text(4.1, 1.7, 'Y0', fontsize=10, fontweight='bold')
plt.savefig('keras_nns_%d.png'%num_plot)
plt.show()

# %%
nfolds=5
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(12, 5)
fig.subplots_adjust(wspace=0.3)
ax1.set_yticks([])
ax1.set_xlim(0,5)
ax1.axison=False
#ax1.set_xticks([i+0.4 for i in nfolds], ['Fold #%d'%i for i in range(5)])
#ax1.text(0, -5, 'Fold #0', fontsize=12, fontweight='bold')
ax1.set_axis_bgcolor("white")
ax1.set_title('Cross Validation',size=16)
ax2.set_xscale('log')
ax2.set_xticks(my_grid)
ax2.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax2.set_ylim([0.34,0.66])
ax2.set_xlim([1.8,6500])
ax2.set_xlabel('# Neurons (Log Scale)',size=14)
ax2.set_ylabel('Validation Loss',size=14)
plt.tight_layout()
fig.subplots_adjust(wspace=0.4)
plt.subplots_adjust(right=0.88)
for nn in range(1,6):
    p00=ax1.bar(range(nn), [100. for i in range(nn)], color = '#D96459')
    p0=ax1.bar(range(nn), [100-16*i for i in range(nn)], color = '#F2E394')
    p1=ax1.bar(range(nn), [100-16*(i+1) for i in range(nn)], color = '#D96459')
    p2=ax1.bar(range(nn), [20. for i in range(nn)], color = '#588C73')
    ax1.legend((p0[0], p1[0], p2[0]), ('Validation', 'Training', 'Test'),bbox_to_anchor=(0.98, 1), loc=2, 
           borderaxespad=0.,prop={'size': 12})
    ax1.text(nn-0.93, -5, 'Fold #%d'%(nn-1), fontsize=12, fontweight='bold')
    plt.savefig('x-valid_%d.png'%nn)
    ax2.plot(my_grid, np.transpose(all_kfolds_results)[nn-1],ms=7,label='Fold #%d'%(nn-1),lw=2)
    ax2.legend(bbox_to_anchor=(1.0, 1), loc=2, prop={'size': 12})
    plt.savefig('x-valid_%d_.png'%nn)
ax2.errorbar(my_grid, np.mean(all_kfolds_results,axis=1), 
                  yerr=np.std(all_kfolds_results,axis=1),label='Average', ms=20,lw=5)
ax2.legend(bbox_to_anchor=(1.0, 1), loc=2, prop={'size': 12})
plt.savefig('x-valid_%d_.png'%(nfolds+1))
ax2.annotate('Winner! (technically)', xy=(200, 0.53), xytext=(40, 0.6),fontsize=14,
            arrowprops=dict(facecolor='black', shrink=0.05))
plt.savefig('x-valid_%d__.png'%(nfolds+1))
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   # Remove the CWD from sys.path while we load stuff.
